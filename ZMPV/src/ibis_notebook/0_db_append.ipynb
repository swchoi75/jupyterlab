# %%
# In Terminal, "pip install ibis-framework[duckdb] pyjanitor"
import pandas as pd
from janitor import clean_names

# %%
# Path
from pathlib import Path
path = Path("~/datasets/home-dataset/jupyterlab/ZMPV")
data_path = path / "data"
db_path = path / "db"

# %%
# Input files
input_file = data_path / "ZMPV_2024_01.txt"

# %%
# DB files
db_file = db_path / "ZMPV_2024.csv"

# %%
def read_txt_file(path):
    # Read a tab-delimited file

    return pd.read_csv(
        path,
        delimiter="\t",
        skiprows=6,
        encoding="UTF-16LE",
        skipinitialspace=True,
        thousands=",",
        # engine='python'  # Error occurs
        dtype={
            "M/Y (from-": str,
            "SAP Plant": str,
            "Outlet": str,
            "Vendor": str,
            "Trading Pr": str,
            "Accounts f": str,
            "Document d": str,
        },
    )

# %%
def remove_col_row(df):
    # Remove first two columns and sub-total rows
    df = df.drop(columns=["Unnamed: 0", "Unnamed: 1"])
    df = df.dropna(subset="Profit Cen")
    return df

# %%
def rename_cols(df):
    new_columns = {
        "Net PPV...23": "Net PPV",
        "Net PM_PPV...24": "Net PPV ratio",
        "STD Other...39": "STD Other",
        "STD Other...40": "STD Other 2",
    }
    return df.rename(columns=new_columns)

# %%
df = read_txt_file(input_file)
df.head(3)
# Out:
#    Unnamed: 0 Unnamed: 1 M/Y (from- Outs./IC SAP Plant Profit Cen Outlet  \
# 0         NaN        NaN   2025.001       IC      0180  50803-009   7311
# 1         NaN        NaN   2025.001       IC      0180  50803-009   7311
# 2         NaN        NaN   2025.001       IC      0180  50803-009   7311
#
#        Vendor                Vendor Name Vendor Cou  ... PPV accoun  \
# 0  0VCC208000  Vitesco Technologies GmbH         DE  ...      K9021
# 1  0VCC208000  Vitesco Technologies GmbH         DE  ...     K90211
# 2  0VCC208000  Vitesco Technologies GmbH         DE  ...     K90211
#
#   IC.Elimin. Subcontrac Actual Cus Accounts f Materia Ty  Psegment  \
# 0          0          0          0        NaN        ROH  208-7311
# 1   -3826252          0          0        NaN        ROH  208-7311
# 2   -7652486          0          0        NaN        ROH  208-7311
#
#    Document d MRP Type        MRP Descrp
# 0         NaN       X1  APO:MRP(P1, ROH)
# 1         NaN       X1  APO:MRP(P1, ROH)
# 2         NaN       X1  APO:MRP(P1, ROH)
#
# [3 rows x 52 columns]

# %%
df = remove_col_row(df)
df.head(3)
# Out:
#   M/Y (from- Outs./IC SAP Plant Profit Cen Outlet      Vendor  \
# 0   2025.001       IC      0180  50803-009   7311  0VCC208000
# 1   2025.001       IC      0180  50803-009   7311  0VCC208000
# 2   2025.001       IC      0180  50803-009   7311  0VCC208000
#
#                  Vendor Name Vendor Cou Trading Pr           TradingPrtnDescr  \
# 0  Vitesco Technologies GmbH         DE       2080  VITESCO TECHNOLOGIES GMBH
# 1  Vitesco Technologies GmbH         DE       2080  VITESCO TECHNOLOGIES GMBH
# 2  Vitesco Technologies GmbH         DE       2080  VITESCO TECHNOLOGIES GMBH
#
#    ... PPV accoun IC.Elimin. Subcontrac Actual Cus Accounts f  Materia Ty  \
# 0  ...      K9021          0          0          0        NaN         ROH
# 1  ...     K90211   -3826252          0          0        NaN         ROH
# 2  ...     K90211   -7652486          0          0        NaN         ROH
#
#    Psegment  Document d MRP Type        MRP Descrp
# 0  208-7311         NaN       X1  APO:MRP(P1, ROH)
# 1  208-7311         NaN       X1  APO:MRP(P1, ROH)
# 2  208-7311         NaN       X1  APO:MRP(P1, ROH)
#
# [3 rows x 50 columns]

# %%
df = rename_cols(df)
df = clean_names(df)
df.head(3)
# Out:
#   m_y_from_ outs_ic sap_plant profit_cen outlet      vendor  \
# 0  2025.001      IC      0180  50803-009   7311  0VCC208000
# 1  2025.001      IC      0180  50803-009   7311  0VCC208000
# 2  2025.001      IC      0180  50803-009   7311  0VCC208000
#
#                  vendor_name vendor_cou trading_pr           tradingprtndescr  \
# 0  Vitesco Technologies GmbH         DE       2080  VITESCO TECHNOLOGIES GMBH
# 1  Vitesco Technologies GmbH         DE       2080  VITESCO TECHNOLOGIES GMBH
# 2  Vitesco Technologies GmbH         DE       2080  VITESCO TECHNOLOGIES GMBH
#
#    ... ppv_accoun ic_elimin_ subcontrac actual_cus accounts_f  materia_ty  \
# 0  ...      K9021          0          0          0        NaN         ROH
# 1  ...     K90211   -3826252          0          0        NaN         ROH
# 2  ...     K90211   -7652486          0          0        NaN         ROH
#
#    psegment  document_d mrp_type        mrp_descrp
# 0  208-7311         NaN       X1  APO:MRP(P1, ROH)
# 1  208-7311         NaN       X1  APO:MRP(P1, ROH)
# 2  208-7311         NaN       X1  APO:MRP(P1, ROH)
#
# [3 rows x 50 columns]

# %%
df.to_csv(db_file, mode="a", header=False, index=False)
