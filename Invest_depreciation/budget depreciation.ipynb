# %%
# In Terminal, "pip install ibis-framework[duckdb] pyjanitor"
import pandas as pd
import ibis
from ibis import selectors as s
from ibis import _
ibis.options.interactive = True

# %%
from janitor import clean_names

# %%
# Path
path = "invest_depreciation/"
data_path = path + "bud_data/"
output_path = path + "bud_output/"

# %%
# Input file
filename = "Budget 2024 Investment and depreciation all_20230913 v2.xlsx"

# %%
# Read excel sheet data and return pandas dataframe and ibis table
df = pd.read_excel(data_path + filename, sheet_name="Asset ledger by Jul. acquis", skiprows=10, usecols="A:AD").clean_names()
# df = df.astype({"asset":str, "ending_date":str, "asset_class":str, "asset_no":str, "new_cc":str, "new_cc_1":str,
#                 "p_o":str, "vendor":str})
df.acquisitio = df.acquisitio.str.replace(".", "-").astype("datetime64[ns]")
df.spending_date = df.spending_date.str.replace(".", "-").astype("datetime64[ns]")
df.odep_start = df.odep_start.str.replace(".", "-").astype("datetime64[ns]")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5370 entries, 0 to 5369
# Data columns (total 30 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   asset              5369 non-null   float64
#  1   gl_account         5369 non-null   object
#  2   ending_date        0 non-null      float64
#  3   cost_elem_         693 non-null    object
#  4   asset_class        5346 non-null   float64
#  5   new_cc             5369 non-null   float64
#  6   new_cc_1           5357 non-null   object
#  7   check              5357 non-null   object
#  8   new_profit_center  5369 non-null   object
#  9   category           5365 non-null   object
#  10  asset_no           5081 non-null   float64
#  11  wbs                83 non-null     object
#  12  project            94 non-null     object
#  13  sub_no             29 non-null     object
#  14  description        5369 non-null   object
#  15  acquisitio         5071 non-null   datetime64[ns]
#  16  spending_date      5071 non-null   datetime64[ns]
#  17  con                5302 non-null   float64
#  18  con_p              649 non-null    float64
#  19  kor                5005 non-null   float64
#  20  sie                4990 non-null   float64
#  21  _acqusition        5361 non-null   float64
#  22  _previous          5081 non-null   float64
#  23  _current           5356 non-null   float64
#  24  _total             5081 non-null   float64
#  25  _book_value        5081 non-null   float64
#  26  vendor_name        4930 non-null   object
#  27  p_o                4662 non-null   object
#  28  vendor             4758 non-null   object
#  29  odep_start         5081 non-null   datetime64[ns]
# dtypes: datetime64[ns](3), float64(14), object(13)
# memory usage: 1.2+ MB

# %%
# Convert pandas dataframe to ibis table
tbl = ibis.memtable(df)
tbl.head(3)
# Out:
# ┏━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┓
# ┃ asset        ┃ gl_account ┃ ending_date ┃ cost_elem_ ┃ asset_class ┃ new_cc  ┃ new_cc_1 ┃ check     ┃ new_profit_center ┃ category      ┃ asset_no     ┃ wbs    ┃ project ┃ sub_no  ┃ description                               ┃ acquisitio          ┃ spending_date       ┃ con     ┃ con_p   ┃ kor     ┃ sie     ┃ _acqusition  ┃ _previous     ┃ _current ┃ _total        ┃ _book_value ┃ vendor_name         ┃ p_o          ┃ vendor  ┃ odep_start          ┃
# ┡━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━┩
# │ float64      │ string     │ float64     │ string     │ float64     │ float64 │ unknown  │ string    │ string            │ string        │ float64      │ string │ string  │ unknown │ string                                    │ timestamp           │ timestamp           │ float64 │ float64 │ float64 │ float64 │ float64      │ float64       │ float64  │ float64       │ float64     │ string              │ unknown      │ unknown │ timestamp           │
# ├──────────────┼────────────┼─────────────┼────────────┼─────────────┼─────────┼──────────┼───────────┼───────────────────┼───────────────┼──────────────┼────────┼─────────┼─────────┼───────────────────────────────────────────┼─────────────────────┼─────────────────────┼─────────┼─────────┼─────────┼─────────┼──────────────┼───────────────┼──────────┼───────────────┼─────────────┼─────────────────────┼──────────────┼─────────┼─────────────────────┤
# │ 1.221420e+08 │ K401       │         nan │ K413       │       131.0 │  2110.0 │ 2110     │ 50899-999 │ 50899-999         │ Assset ledger │ 1.310008e+07 │ NULL   │ NULL    │ '2'     │ Contract worker management (s/w addition) │ 2005-11-01 00:00:00 │ 2005-11-01 00:00:00 │     3.0 │     nan │     4.0 │     3.0 │ 2.444444e+06 │ -2.444444e+06 │      0.0 │ -2.444444e+06 │         0.0 │ SAMBO               │ '4100002267' │ '20082' │ 2005-11-01 00:00:00 │
# │ 1.221420e+08 │ K401       │         nan │ K413       │       131.0 │  2110.0 │ 2110     │ 50899-999 │ 50899-999         │ Assset ledger │ 1.310008e+07 │ NULL   │ NULL    │ NULL    │ Year-end tax settlement-s/w improvement   │ 2006-07-31 00:00:00 │ 2006-07-31 00:00:00 │     3.0 │     nan │     4.0 │     3.0 │ 2.638888e+06 │ -2.638888e+06 │      0.0 │ -2.638888e+06 │         0.0 │ SAMBO               │ '4100005315' │ '21239' │ 2006-07-01 00:00:00 │
# │ 1.221420e+08 │ K401       │         nan │ NULL       │       131.0 │  5248.0 │ 5248     │ 50803-042 │ 50803-042         │ Assset ledger │ 1.310012e+07 │ NULL   │ NULL    │ NULL    │ Matlab_Simulink (SW tool set)             │ 2005-11-02 00:00:00 │ 2005-11-02 00:00:00 │     3.0 │     nan │     4.0 │     3.0 │ 1.038583e+07 │ -1.038583e+07 │      0.0 │ -1.038583e+07 │         0.0 │ The MathWorks KOREA │ '4100003479' │ '21273' │ 2005-11-01 00:00:00 │
# └──────────────┴────────────┴─────────────┴────────────┴─────────────┴─────────┴──────────┴───────────┴───────────────────┴───────────────┴──────────────┴────────┴─────────┴─────────┴───────────────────────────────────────────┴─────────────────────┴─────────────────────┴─────────┴─────────┴─────────┴─────────┴──────────────┴───────────────┴──────────┴───────────────┴─────────────┴─────────────────────┴──────────────┴─────────┴─────────────────────┘

# %%
# Change data type from Unknown to String
tbl = tbl.cast({"asset":str, "asset_class":str, "asset_no":str, "new_cc":str, "new_cc_1":str, "p_o":str, "vendor":str,
                "con":int, "con_p":int, "kor":int, "sie":int, "_acqusition":int, "_previous":int, "_current":int, "_total":int, "_book_value":int, })
tbl.head(3)
# Out:
# ┏━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━┳━━━━━━━┳━━━━━━━┳━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┓
# ┃ asset       ┃ gl_account ┃ ending_date ┃ cost_elem_ ┃ asset_class ┃ new_cc ┃ new_cc_1 ┃ check     ┃ new_profit_center ┃ category      ┃ asset_no   ┃ wbs    ┃ project ┃ sub_no  ┃ description                               ┃ acquisitio          ┃ spending_date       ┃ con   ┃ con_p ┃ kor   ┃ sie   ┃ _acqusition ┃ _previous ┃ _current ┃ _total    ┃ _book_value ┃ vendor_name         ┃ p_o        ┃ vendor ┃ odep_start          ┃
# ┡━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━╇━━━━━━━╇━━━━━━━╇━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━┩
# │ string      │ string     │ float64     │ string     │ string      │ string │ string   │ string    │ string            │ string        │ string     │ string │ string  │ unknown │ string                                    │ timestamp           │ timestamp           │ int64 │ int64 │ int64 │ int64 │ int64       │ int64     │ int64    │ int64     │ int64       │ string              │ string     │ string │ timestamp           │
# ├─────────────┼────────────┼─────────────┼────────────┼─────────────┼────────┼──────────┼───────────┼───────────────────┼───────────────┼────────────┼────────┼─────────┼─────────┼───────────────────────────────────────────┼─────────────────────┼─────────────────────┼───────┼───────┼───────┼───────┼─────────────┼───────────┼──────────┼───────────┼─────────────┼─────────────────────┼────────────┼────────┼─────────────────────┤
# │ 122142000.0 │ K401       │         nan │ K413       │ 131.0       │ 2110.0 │ 2110     │ 50899-999 │ 50899-999         │ Assset ledger │ 13100080.0 │ NULL   │ NULL    │ '2'     │ Contract worker management (s/w addition) │ 2005-11-01 00:00:00 │ 2005-11-01 00:00:00 │     3 │  NULL │     4 │     3 │     2444444 │  -2444444 │        0 │  -2444444 │           0 │ SAMBO               │ 4100002267 │ 20082  │ 2005-11-01 00:00:00 │
# │ 122142000.0 │ K401       │         nan │ K413       │ 131.0       │ 2110.0 │ 2110     │ 50899-999 │ 50899-999         │ Assset ledger │ 13100080.0 │ NULL   │ NULL    │ NULL    │ Year-end tax settlement-s/w improvement   │ 2006-07-31 00:00:00 │ 2006-07-31 00:00:00 │     3 │  NULL │     4 │     3 │     2638888 │  -2638888 │        0 │  -2638888 │           0 │ SAMBO               │ 4100005315 │ 21239  │ 2006-07-01 00:00:00 │
# │ 122142000.0 │ K401       │         nan │ NULL       │ 131.0       │ 5248.0 │ 5248     │ 50803-042 │ 50803-042         │ Assset ledger │ 13100120.0 │ NULL   │ NULL    │ NULL    │ Matlab_Simulink (SW tool set)             │ 2005-11-02 00:00:00 │ 2005-11-02 00:00:00 │     3 │  NULL │     4 │     3 │    10385834 │ -10385834 │        0 │ -10385834 │           0 │ The MathWorks KOREA │ 4100003479 │ 21273  │ 2005-11-01 00:00:00 │
# └─────────────┴────────────┴─────────────┴────────────┴─────────────┴────────┴──────────┴───────────┴───────────────────┴───────────────┴────────────┴────────┴─────────┴─────────┴───────────────────────────────────────────┴─────────────────────┴─────────────────────┴───────┴───────┴───────┴───────┴─────────────┴───────────┴──────────┴───────────┴─────────────┴─────────────────────┴────────────┴────────┴─────────────────────┘

# %%
# Remove ".0" in string data
tbl = tbl.mutate(
    asset=_.asset.replace(".0", ""),
    asset_class=_.asset_class.replace(".0", ""),
    new_cc=_.new_cc.replace(".0", ""),
    asset_no=_.asset_no.replace(".0", ""),
)
tbl.head(3)
# Out:
# ┏━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━┳━━━━━━━┳━━━━━━━┳━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┓
# ┃ asset     ┃ gl_account ┃ ending_date ┃ cost_elem_ ┃ asset_class ┃ new_cc ┃ new_cc_1 ┃ check     ┃ new_profit_center ┃ category      ┃ asset_no ┃ wbs    ┃ project ┃ sub_no  ┃ description                               ┃ acquisitio          ┃ spending_date       ┃ con   ┃ con_p ┃ kor   ┃ sie   ┃ _acqusition ┃ _previous ┃ _current ┃ _total    ┃ _book_value ┃ vendor_name         ┃ p_o        ┃ vendor ┃ odep_start          ┃
# ┡━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━╇━━━━━━━╇━━━━━━━╇━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━┩
# │ string    │ string     │ float64     │ string     │ string      │ string │ string   │ string    │ string            │ string        │ string   │ string │ string  │ unknown │ string                                    │ timestamp           │ timestamp           │ int64 │ int64 │ int64 │ int64 │ int64       │ int64     │ int64    │ int64     │ int64       │ string              │ string     │ string │ timestamp           │
# ├───────────┼────────────┼─────────────┼────────────┼─────────────┼────────┼──────────┼───────────┼───────────────────┼───────────────┼──────────┼────────┼─────────┼─────────┼───────────────────────────────────────────┼─────────────────────┼─────────────────────┼───────┼───────┼───────┼───────┼─────────────┼───────────┼──────────┼───────────┼─────────────┼─────────────────────┼────────────┼────────┼─────────────────────┤
# │ 122142000 │ K401       │         nan │ K413       │ 131         │ 2110   │ 2110     │ 50899-999 │ 50899-999         │ Assset ledger │ 13100080 │ NULL   │ NULL    │ '2'     │ Contract worker management (s/w addition) │ 2005-11-01 00:00:00 │ 2005-11-01 00:00:00 │     3 │  NULL │     4 │     3 │     2444444 │  -2444444 │        0 │  -2444444 │           0 │ SAMBO               │ 4100002267 │ 20082  │ 2005-11-01 00:00:00 │
# │ 122142000 │ K401       │         nan │ K413       │ 131         │ 2110   │ 2110     │ 50899-999 │ 50899-999         │ Assset ledger │ 13100080 │ NULL   │ NULL    │ NULL    │ Year-end tax settlement-s/w improvement   │ 2006-07-31 00:00:00 │ 2006-07-31 00:00:00 │     3 │  NULL │     4 │     3 │     2638888 │  -2638888 │        0 │  -2638888 │           0 │ SAMBO               │ 4100005315 │ 21239  │ 2006-07-01 00:00:00 │
# │ 122142000 │ K401       │         nan │ NULL       │ 131         │ 5248   │ 5248     │ 50803-042 │ 50803-042         │ Assset ledger │ 13100120 │ NULL   │ NULL    │ NULL    │ Matlab_Simulink (SW tool set)             │ 2005-11-02 00:00:00 │ 2005-11-02 00:00:00 │     3 │  NULL │     4 │     3 │    10385834 │ -10385834 │        0 │ -10385834 │           0 │ The MathWorks KOREA │ 4100003479 │ 21273  │ 2005-11-01 00:00:00 │
# └───────────┴────────────┴─────────────┴────────────┴─────────────┴────────┴──────────┴───────────┴───────────────────┴───────────────┴──────────┴────────┴─────────┴─────────┴───────────────────────────────────────────┴─────────────────────┴─────────────────────┴───────┴───────┴───────┴───────┴─────────────┴───────────┴──────────┴───────────┴─────────────┴─────────────────────┴────────────┴────────┴─────────────────────┘

# %%
# Remove unnecessary columns
columns_to_exclude = ["ending_date", "cost_elem_", "new_cc_1", "check", "wbs", "project", "sub_no", "vendor", "vendor_name", "p_o"]
selected_columns = [col for col in tbl.columns if col not in columns_to_exclude]
tbl = tbl.select(selected_columns)
tbl.head(3)
# Out:
# ┏━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━┳━━━━━━━┳━━━━━━━┳━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┓
# ┃ asset     ┃ gl_account ┃ asset_class ┃ new_cc ┃ new_profit_center ┃ category      ┃ asset_no ┃ description                               ┃ acquisitio          ┃ spending_date       ┃ con   ┃ con_p ┃ kor   ┃ sie   ┃ _acqusition ┃ _previous ┃ _current ┃ _total    ┃ _book_value ┃ odep_start          ┃
# ┡━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━╇━━━━━━━╇━━━━━━━╇━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━┩
# │ string    │ string     │ string      │ string │ string            │ string        │ string   │ string                                    │ timestamp           │ timestamp           │ int64 │ int64 │ int64 │ int64 │ int64       │ int64     │ int64    │ int64     │ int64       │ timestamp           │
# ├───────────┼────────────┼─────────────┼────────┼───────────────────┼───────────────┼──────────┼───────────────────────────────────────────┼─────────────────────┼─────────────────────┼───────┼───────┼───────┼───────┼─────────────┼───────────┼──────────┼───────────┼─────────────┼─────────────────────┤
# │ 122142000 │ K401       │ 131         │ 2110   │ 50899-999         │ Assset ledger │ 13100080 │ Contract worker management (s/w addition) │ 2005-11-01 00:00:00 │ 2005-11-01 00:00:00 │     3 │  NULL │     4 │     3 │     2444444 │  -2444444 │        0 │  -2444444 │           0 │ 2005-11-01 00:00:00 │
# │ 122142000 │ K401       │ 131         │ 2110   │ 50899-999         │ Assset ledger │ 13100080 │ Year-end tax settlement-s/w improvement   │ 2006-07-31 00:00:00 │ 2006-07-31 00:00:00 │     3 │  NULL │     4 │     3 │     2638888 │  -2638888 │        0 │  -2638888 │           0 │ 2006-07-01 00:00:00 │
# │ 122142000 │ K401       │ 131         │ 5248   │ 50803-042         │ Assset ledger │ 13100120 │ Matlab_Simulink (SW tool set)             │ 2005-11-02 00:00:00 │ 2005-11-02 00:00:00 │     3 │  NULL │     4 │     3 │    10385834 │ -10385834 │        0 │ -10385834 │           0 │ 2005-11-01 00:00:00 │
# └───────────┴────────────┴─────────────┴────────┴───────────────────┴───────────────┴──────────┴───────────────────────────────────────────┴─────────────────────┴─────────────────────┴───────┴───────┴───────┴───────┴─────────────┴───────────┴──────────┴───────────┴─────────────┴─────────────────────┘

# %%
depr = tbl.group_by(["category", "new_profit_center", "new_cc"]).aggregate(_._current.sum())
depr.head(3)
# Out:
# ┏━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ category      ┃ new_profit_center ┃ new_cc ┃ Sum(_current) ┃
# ┡━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ string        │ string            │ string │ int64         │
# ├───────────────┼───────────────────┼────────┼───────────────┤
# │ Assset ledger │ 50899-999         │ 30801  │             0 │
# │ Assset ledger │ 50803-042         │ 5131   │    -118434226 │
# │ Assset ledger │ 50802-018         │ 34854  │    -668800000 │
# └───────────────┴───────────────────┴────────┴───────────────┘

# %%
# Output data
depr.to_pandas().to_csv(output_path + "investment_depreciation.csv", index=False)

# %% [markdown]
# ### Monthly calculation

# %%
df_month_ends = pd.DataFrame({"months": pd.date_range('2024-01-31', '2025-01-01', freq='M')})
df_month_ends.head(3)
# Out:
#       months
# 0 2024-01-31
# 1 2024-02-29
# 2 2024-03-31

# %%
month_ends = ibis.memtable(df_month_ends)
month_ends.head(3)
# Out:
# ┏━━━━━━━━━━━━━━━━━━━━━┓
# ┃ months              ┃
# ┡━━━━━━━━━━━━━━━━━━━━━┩
# │ timestamp           │
# ├─────────────────────┤
# │ 2024-01-31 00:00:00 │
# │ 2024-02-29 00:00:00 │
# │ 2024-03-31 00:00:00 │
# └─────────────────────┘

# %%
# Cross Join two tables
t = month_ends.join(tbl, how="cross")
t.head(3)
# Out:
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━┳━━━━━━━┳━━━━━━━┳━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┓
# ┃ months              ┃ asset     ┃ gl_account ┃ asset_class ┃ new_cc ┃ new_profit_center ┃ category      ┃ asset_no ┃ description                               ┃ acquisitio          ┃ spending_date       ┃ con   ┃ con_p ┃ kor   ┃ sie   ┃ _acqusition ┃ _previous ┃ _current ┃ _total    ┃ _book_value ┃ odep_start          ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━╇━━━━━━━╇━━━━━━━╇━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━┩
# │ timestamp           │ string    │ string     │ string      │ string │ string            │ string        │ string   │ string                                    │ timestamp           │ timestamp           │ int64 │ int64 │ int64 │ int64 │ int64       │ int64     │ int64    │ int64     │ int64       │ timestamp           │
# ├─────────────────────┼───────────┼────────────┼─────────────┼────────┼───────────────────┼───────────────┼──────────┼───────────────────────────────────────────┼─────────────────────┼─────────────────────┼───────┼───────┼───────┼───────┼─────────────┼───────────┼──────────┼───────────┼─────────────┼─────────────────────┤
# │ 2024-01-31 00:00:00 │ 122142000 │ K401       │ 131         │ 2110   │ 50899-999         │ Assset ledger │ 13100080 │ Contract worker management (s/w addition) │ 2005-11-01 00:00:00 │ 2005-11-01 00:00:00 │     3 │  NULL │     4 │     3 │     2444444 │  -2444444 │        0 │  -2444444 │           0 │ 2005-11-01 00:00:00 │
# │ 2024-01-31 00:00:00 │ 122142000 │ K401       │ 131         │ 2110   │ 50899-999         │ Assset ledger │ 13100080 │ Year-end tax settlement-s/w improvement   │ 2006-07-31 00:00:00 │ 2006-07-31 00:00:00 │     3 │  NULL │     4 │     3 │     2638888 │  -2638888 │        0 │  -2638888 │           0 │ 2006-07-01 00:00:00 │
# │ 2024-01-31 00:00:00 │ 122142000 │ K401       │ 131         │ 5248   │ 50803-042         │ Assset ledger │ 13100120 │ Matlab_Simulink (SW tool set)             │ 2005-11-02 00:00:00 │ 2005-11-02 00:00:00 │     3 │  NULL │     4 │     3 │    10385834 │ -10385834 │        0 │ -10385834 │           0 │ 2005-11-01 00:00:00 │
# └─────────────────────┴───────────┴────────────┴─────────────┴────────┴───────────────────┴───────────────┴──────────┴───────────────────────────────────────────┴─────────────────────┴─────────────────────┴───────┴───────┴───────┴───────┴─────────────┴───────────┴──────────┴───────────┴─────────────┴─────────────────────┘

# %%
t = t.mutate(
    current_depr=_._acqusition / _.con / 12,
    depr_start=_.acquisitio,
    # depr_end=_.acquisitio + _.con * 12 * 30,
    )
t.head(3)
# Out:
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━┳━━━━━━━┳━━━━━━━┳━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━┓
# ┃ months              ┃ asset     ┃ gl_account ┃ asset_class ┃ new_cc ┃ new_profit_center ┃ category      ┃ asset_no ┃ description                               ┃ acquisitio          ┃ spending_date       ┃ con   ┃ con_p ┃ kor   ┃ sie   ┃ _acqusition ┃ _previous ┃ _current ┃ _total    ┃ _book_value ┃ odep_start          ┃ current_depr  ┃ depr_start          ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━╇━━━━━━━╇━━━━━━━╇━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━┩
# │ timestamp           │ string    │ string     │ string      │ string │ string            │ string        │ string   │ string                                    │ timestamp           │ timestamp           │ int64 │ int64 │ int64 │ int64 │ int64       │ int64     │ int64    │ int64     │ int64       │ timestamp           │ float64       │ timestamp           │
# ├─────────────────────┼───────────┼────────────┼─────────────┼────────┼───────────────────┼───────────────┼──────────┼───────────────────────────────────────────┼─────────────────────┼─────────────────────┼───────┼───────┼───────┼───────┼─────────────┼───────────┼──────────┼───────────┼─────────────┼─────────────────────┼───────────────┼─────────────────────┤
# │ 2024-01-31 00:00:00 │ 122142000 │ K401       │ 131         │ 2110   │ 50899-999         │ Assset ledger │ 13100080 │ Contract worker management (s/w addition) │ 2005-11-01 00:00:00 │ 2005-11-01 00:00:00 │     3 │  NULL │     4 │     3 │     2444444 │  -2444444 │        0 │  -2444444 │           0 │ 2005-11-01 00:00:00 │  67901.222222 │ 2005-11-01 00:00:00 │
# │ 2024-01-31 00:00:00 │ 122142000 │ K401       │ 131         │ 2110   │ 50899-999         │ Assset ledger │ 13100080 │ Year-end tax settlement-s/w improvement   │ 2006-07-31 00:00:00 │ 2006-07-31 00:00:00 │     3 │  NULL │     4 │     3 │     2638888 │  -2638888 │        0 │  -2638888 │           0 │ 2006-07-01 00:00:00 │  73302.444444 │ 2006-07-31 00:00:00 │
# │ 2024-01-31 00:00:00 │ 122142000 │ K401       │ 131         │ 5248   │ 50803-042         │ Assset ledger │ 13100120 │ Matlab_Simulink (SW tool set)             │ 2005-11-02 00:00:00 │ 2005-11-02 00:00:00 │     3 │  NULL │     4 │     3 │    10385834 │ -10385834 │        0 │ -10385834 │           0 │ 2005-11-01 00:00:00 │ 288495.388889 │ 2005-11-02 00:00:00 │
# └─────────────────────┴───────────┴────────────┴─────────────┴────────┴───────────────────┴───────────────┴──────────┴───────────────────────────────────────────┴─────────────────────┴─────────────────────┴───────┴───────┴───────┴───────┴─────────────┴───────────┴──────────┴───────────┴─────────────┴─────────────────────┴───────────────┴─────────────────────┘

# %%
# Output data
t.to_pandas().to_csv(output_path + "investment_depreciation_monthly.csv", index=False)
