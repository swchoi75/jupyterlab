# %%
# In Terminal, "pip install ibis-framework[duckdb] pyjanitor"
import pandas as pd
from janitor import clean_names

# %%
# Path
from pathlib import Path
path = Path("~/datasets/home-dataset/jupyterlab/ZVAR")
data_path = path / "data"
db_path = path / "db"

# %%
# Input files
input_file = data_path / "ZVAR_2023_11.txt"

# %%
# DB files
db_file = db_path / "ZVAR_2023.csv"

# %%
def read_txt_file(path):
    # Read a tab-delimited file
    return pd.read_csv(
        path,
        sep="\t",
        skiprows=8,
        encoding="UTF-16LE",
        skipinitialspace=True,
        thousands=",",
        engine="python",
        dtype={
            "Order": str,
            "Cost Ctr": str,
            "Blk-Ind": str,
            "No-Post": str,
        },           
    )

# %%
def remove_col_row(df):
    # Remove first two columns and sub-total rows
    df = df.drop(columns=["Unnamed: 0", "Unnamed: 1", "Unnamed: 4"])
    df = df.dropna(subset=["Order"])
    # Remove repeating header rows
    df = df[df.ne(df.columns).any(axis="columns")]
    return df

# %%
df = read_txt_file(input_file)
df.head(3)
# Out:
#   Unnamed: 0 Unnamed: 1   Order  Material Unnamed: 4 Cost Elem. CE act  \
# 0        NaN        NaN  756325  1802CF8T        NaN       K020    NaN
# 1        NaN        NaN  756325  1802CF8T        NaN       K020    NaN
# 2        NaN        NaN  756325  1802CF8T        NaN       K020    NaN
#
#     COmaterial BTran Cost Ctr  ...  COAr Resp. CCtr Crcy   Object number  \
# 0  A2C00013954   NaN      NaN  ...  5668        NaN  KRW  OR000000756325
# 1  A2C81641700   NaN      NaN  ...  5668        NaN  KRW  OR000000756325
# 2  A2C93346100   NaN      NaN  ...  5668        NaN  KRW  OR000000756325
#
#    Prod.Proc Le Vsn CO subkey Partner Object Source Object
# 0  100366251  0   0      None           None          None
# 1  100366251  0   0      None           None          None
# 2  100366251  0   0      None           None          None
#
# [3 rows x 59 columns]

# %%
df = remove_col_row(df)
df.head(3)
# Out:
#     Order  Material Cost Elem. CE act   COmaterial BTran Cost Ctr ActTyp D/C  \
# 0  756325  1802CF8T       K020    NaN  A2C00013954   NaN      NaN    NaN   D
# 1  756325  1802CF8T       K020    NaN  A2C81641700   NaN      NaN    NaN   D
# 2  756325  1802CF8T       K020    NaN  A2C93346100   NaN      NaN    NaN   D
#
#    UM  ...  COAr Resp. CCtr Crcy   Object number  Prod.Proc Le Vsn CO subkey  \
# 0  ST  ...  5668        NaN  KRW  OR000000756325  100366251  0   0      None
# 1  ST  ...  5668        NaN  KRW  OR000000756325  100366251  0   0      None
# 2  ST  ...  5668        NaN  KRW  OR000000756325  100366251  0   0      None
#
#   Partner Object Source Object
# 0           None          None
# 1           None          None
# 2           None          None
#
# [3 rows x 56 columns]

# %%
df = clean_names(df)
df.head(3)
# Out:
#     order  material cost_elem_ ce_act   comaterial btran cost_ctr acttyp d_c  \
# 0  756325  1802CF8T       K020    NaN  A2C00013954   NaN      NaN    NaN   D
# 1  756325  1802CF8T       K020    NaN  A2C81641700   NaN      NaN    NaN   D
# 2  756325  1802CF8T       K020    NaN  A2C93346100   NaN      NaN    NaN   D
#
#    um  ...  coar resp_cctr crcy   object_number  prod_proc le vsn co_subkey  \
# 0  ST  ...  5668       NaN  KRW  OR000000756325  100366251  0   0      None
# 1  ST  ...  5668       NaN  KRW  OR000000756325  100366251  0   0      None
# 2  ST  ...  5668       NaN  KRW  OR000000756325  100366251  0   0      None
#
#   partner_object source_object
# 0           None          None
# 1           None          None
# 2           None          None
#
# [3 rows x 56 columns]

# %%
df.to_csv(db_file, mode="a", header=False, index=False)
